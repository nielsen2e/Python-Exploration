# %% [markdown]
# ## Imports
# ** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline **

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# ## Get the Data
#
#
# ** Read in the movies csv file as a DataFrame called data.**

# %%
data = pd.read_csv('movies1.csv')
data
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %% [markdown]
# **Check the head of data, and check out its info() and describe() methods.**

# %%
data.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
data.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.665000e+03  5.497000e+03  7.479000e+03
# mean   2000.405451     6.390411  8.810850e+04  3.558988e+07  7.850054e+07
# std      11.153508     0.968842  1.633238e+05  4.145730e+07  1.657251e+08
# min    1980.000000     1.900000  7.000000e+00  3.000000e+03  3.090000e+02
# 25%    1991.000000     5.800000  9.100000e+03  1.000000e+07  4.532056e+06
# 50%    2000.000000     6.500000  3.300000e+04  2.050000e+07  2.020576e+07
# 75%    2010.000000     7.100000  9.300000e+04  4.500000e+07  7.601669e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %% [markdown]
# ## Exploratory Data Analysis
#
# **Let's explore the data!**

# %% [markdown]
# #### Highest grossing movie per year

# %%
CompanySum = data.groupby(['company', 'year'])[["gross"]].sum()

CompanySorted = CompanySum.sort_values(['gross', 'company', 'year'], ascending = False)[:10]

CompanySorted
# Out:
#                                    gross
# company               year
# Walt Disney Pictures  2019  5.773132e+09
# Marvel Studios        2018  4.018632e+09
# Universal Pictures    2015  3.834355e+09
# Twentieth Century Fox 2009  3.793491e+09
# Walt Disney Pictures  2017  3.789382e+09
# Paramount Pictures    2011  3.565705e+09
# Warner Bros.          2010  3.300480e+09
#                       2011  3.223799e+09
# Walt Disney Pictures  2010  3.104474e+09
# Paramount Pictures    2014  3.071299e+09

# %% [markdown]
# #### The name of the Highest grossing movie

# %%
data[data['gross'] == data['gross'].max()]
# Out:
#         name rating   genre  year                           released  score  \
# 5445  Avatar  PG-13  Action  2009  December 18, 2009 (United States)    7.8
#
#           votes       director         writer             star        country  \
# 5445  1100000.0  James Cameron  James Cameron  Sam Worthington  United States
#
#            budget         gross                company  runtime
# 5445  237000000.0  2.847246e+09  Twentieth Century Fox    162.0

# %% [markdown]
# #### The name of the Lowest grossing movie

# %%
data[data['gross'] == data['gross'].min()]
# Out:
#             name rating   genre  year                  released  score  \
# 3203  Trojan War  PG-13  Comedy  1997  October 1, 1997 (Brazil)    5.7
#
#        votes      director     writer          star        country  \
# 3203  5800.0  George Huang  Andy Burg  Will Friedle  United States
#
#           budget  gross   company  runtime
# 3203  15000000.0  309.0  Daybreak     85.0

# %% [markdown]
# #### What movies did Robert Downey Jr. act star in ?

# %%
data[data['star'] == 'Robert Downey Jr.'][['name', 'year']]
# Out:
#                                     name  year
# 1391                                1969  1988
# 2077                             Chaplin  1992
# 2344                     Heart and Souls  1993
# 2791                         Restoration  1995
# 3207                 Two Girls and a Guy  1997
# 4415               The Singing Detective  2003
# 4577                                Eros  2004
# 4683                 Kiss Kiss Bang Bang  2005
# 5030  A Guide to Recognizing Your Saints  2006
# 5245                            Iron Man  2008
# 5458                     Sherlock Holmes  2009
# 5644                          Iron Man 2  2010
# 5719                            Due Date  2010
# 5891  Sherlock Holmes: A Game of Shadows  2011
# 6043                        The Avengers  2012
# 6244                          Iron Man 3  2013
# 6470                           The Judge  2014
# 6644             Avengers: Age of Ultron  2015
# 7244              Avengers: Infinity War  2018
# ...

# %% [markdown]
# #### What are the top 5 most common companies?

# %%
data['company'].value_counts().head()
# Out:
# Universal Pictures       377
# Warner Bros.             334
# Columbia Pictures        332
# Paramount Pictures       320
# Twentieth Century Fox    240
# Name: company, dtype: int64

# %%
# Let's check for missing data 
for col in data.columns:
    pct_missing = np.mean(data[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
#Let's look at all the data

pd.set_option('display.max_rows', None)

# %%
# Let's drop any duplicates in company column

# data.drop_duplicates() -- To drop the values of all the columns
# We are checking to see if there are issues in the data e.g walt disney changed name during different times
# due to different timeframes

data['company'].drop_duplicates().sort_values(ascending = False).head()
# Out:
# 7129                     thefyzz
# 5664                 micro_scope
# 6412    iDeal Partners Film Fund
# 4007                    i5 Films
# 6793                  i am OTHER
# Name: company, dtype: object

# %%
# Let's check for columns correlated to gross revenue
# Looking at the ones with high correlation
# Budget has a high correlation
# Company name high correlation

# %%
# Lets compare budget and gross revenue using scatter plot

plt.scatter(x = data['budget'], y = data['gross'])

plt.title('Budget vs Gross Revenue')

plt.xlabel('Budget for Movies')
plt.ylabel('Gross Revenue')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.stripplot(x="rating", y="gross", data=data)

# %%
data.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
#Lets do a regression plot to check for correlation
# This shows a postive correlation because its going up

sns.regplot(x = 'budget', y = 'gross', data=data, scatter_kws = {'color':'red'}, line_kws = {'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Lets start looking at correlation
# correlation works on numerical values
#methods of correlation; pearson, kendall, spearman
data.corr(method = 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
# High correlation between budget and gross
#Lets vizualize the correlation matrix

correlation_matrix = data.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)


plt.title('Correlation matrix for numeric features')

plt.xlabel('Movie features')
plt.ylabel('Movie features')

plt.show()

# %%
# lets look at Company
# Lets change company to a numeric feature to be able to get more correlations

data.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
df_numerized = data
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime
# 0  1047       54  19000000.0   46998772.0     2319    146.0
# 1   327       55   4500000.0   58853106.0      731    104.0
# 2  1745       55  18000000.0  538375067.0     1540    124.0
# 3  2246       55   3500000.0   83453539.0     1812     88.0
# 4   410       55   6000000.0   39846344.0     1777     98.0

# %%
data
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
#Lets vizualize the numerized correlation matrix

correlation_matrix = df_numerized.corr(method = 'pearson')

sns.heatmap(correlation_matrix, annot = True)


plt.title('Correlation matrix for numeric features')

plt.xlabel('Movie features')
plt.ylabel('Movie features')

plt.show()

# %%
# Lets organize the data to see the ones with the highest corelation
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs.head()
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released   -0.011311
# dtype: float64

# %%
# Lets sort the pairs
sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head()
# Out:
# budget  genre    -0.356564
# genre   budget   -0.356564
#         gross    -0.235650
# gross   genre    -0.235650
# rating  budget   -0.176002
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.4]
                         
high_corr
# Out:
# score     votes       0.409182
# votes     score       0.409182
# budget    votes       0.442429
# votes     budget      0.442429
# gross     votes       0.630757
# votes     gross       0.630757
# budget    gross       0.740395
# gross     budget      0.740395
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %% [markdown]
# #### Votes and budget have the highests correlation to gross earnings
